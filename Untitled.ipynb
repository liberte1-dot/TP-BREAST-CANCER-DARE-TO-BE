# %%
# 🔬 1. Caractéristiques cellulaires les plus influentes
# 🧬 Taille et forme des cellules

# Radius (rayon) : les tumeurs malignes ont souvent un rayon plus grand

# Area (surface) : surface plus élevée → risque accru

# Perimeter (périmètre) : périmètre irrégulier et élevé

# 👉 Les cellules cancéreuses ont tendance à être plus grandes

# 🔺 Irrégularité de la forme

# Concavity : profondeur des creux du contour

# Concave points : nombre de points concaves

# Compactness : 
# 𝑝
# 𝑒
# ˊ
# 𝑟
# 𝑖
# 𝑚
# 𝑒
# ˋ
# 𝑡
# 𝑟
# 𝑒
# 2
# 𝑠
# 𝑢
# 𝑟
# 𝑓
# 𝑎
# 𝑐
# 𝑒
# surface
# p
# e
# ˊ
# rim
# e
# ˋ
# tre
# 2
# 	​


# 👉 Une tumeur maligne a une forme irrégulière, non lisse

# 📉 Texture et homogénéité

# Texture : variation des niveaux de gris

# Smoothness : régularité des bords

# Symmetry : asymétrie de la forme

# 👉 Le cancer présente souvent :

# texture hétérogène

# asymétrie marquée

# 🧪 Variabilité (Mean, Worst, SE)

# Chaque caractéristique est souvent mesurée sous 3 formes :

# Mean (moyenne)

# SE (erreur standard)

# Worst (valeur maximale)

# 👉 Les valeurs “worst” sont très discriminantes pour détecter le cancer

# 📊 2. Caractéristiques les plus prédictives (selon analyses ML)

# Les plus influentes pour prédire un cancer du sein sont généralement :

# Worst concave points

# Worst radius

# Worst perimeter

# Mean concavity

# Mean compactness

# Worst area

# Worst texture

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.preprocessing import StandardScaler, MinMaxScaler
from sklearn.model_selection import train_test_split

import warnings
warnings.filterwarnings("ignore")

# %%
df = pd.read_csv("breast-cancer.csv")
df.head()
# Out:
#          id diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0    842302         M        17.99         10.38          122.80     1001.0
# 1    842517         M        20.57         17.77          132.90     1326.0
# 2  84300903         M        19.69         21.25          130.00     1203.0
# 3  84348301         M        11.42         20.38           77.58      386.1
# 4  84358402         M        20.29         14.34          135.10     1297.0
#
#    smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# 0          0.11840           0.27760          0.3001              0.14710
# 1          0.08474           0.07864          0.0869              0.07017
# 2          0.10960           0.15990          0.1974              0.12790
# 3          0.14250           0.28390          0.2414              0.10520
# 4          0.10030           0.13280          0.1980              0.10430
#
# ...

# %%
df.shape
# Out:
# (569, 32)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 569 entries, 0 to 568
# Data columns (total 32 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   id                       569 non-null    int64
#  1   diagnosis                569 non-null    object
#  2   radius_mean              569 non-null    float64
#  3   texture_mean             569 non-null    float64
#  4   perimeter_mean           569 non-null    float64
#  5   area_mean                569 non-null    float64
#  6   smoothness_mean          569 non-null    float64
#  7   compactness_mean         569 non-null    float64
#  8   concavity_mean           569 non-null    float64
#  9   concave points_mean      569 non-null    float64
#  10  symmetry_mean            569 non-null    float64
#  11  fractal_dimension_mean   569 non-null    float64
#  12  radius_se                569 non-null    float64
#  13  texture_se               569 non-null    float64
# ...

# %%
#Y-a t'il des valeurs manquantes
df.isnull().sum()
# Out:
# id                         0
# diagnosis                  0
# radius_mean                0
# texture_mean               0
# perimeter_mean             0
# area_mean                  0
# smoothness_mean            0
# compactness_mean           0
# concavity_mean             0
# concave points_mean        0
# symmetry_mean              0
# fractal_dimension_mean     0
# radius_se                  0
# texture_se                 0
# perimeter_se               0
# area_se                    0
# smoothness_se              0
# compactness_se             0
# concavity_se               0
# concave points_se          0
# symmetry_se                0
# fractal_dimension_se       0
# radius_worst               0
# texture_worst              0
# perimeter_worst            0
# area_worst                 0
# smoothness_worst           0
# compactness_worst          0
# concavity_worst            0
# concave points_worst       0
# symmetry_worst             0
# fractal_dimension_worst    0
# ...

# %%
#Presence de doublons
df.duplicated().sum()
# Out:
# 0

# %%
#Encodons la variable cible
df["diagnosis"].value_counts()
# Out:
# diagnosis
# B    357
# M    212
# Name: count, dtype: int64

# %%
# Encodage de la colonne diagnosis
df.diagnosis = df["diagnosis"].replace(["M", "B"], [0, 1])
#df.diagnosis = df["diagnosis"].replace({"M" : 0, "B" : 1})

# %%
#Suppression de la colonne id
df.drop("id", axis = 1, inplace = True)

# %%
#ID est elle encore parmis nos colonnes ?

"id" in df.columns
# Out:
# False

# %% [markdown]
# # 2. Analyse exploratoire

# %% [markdown]
# ## 2.1 Statistique descriptive

# %%
desc_stats = df.describe().T
desc_stats
# Out:
#                          count        mean         std         min  \
# diagnosis                569.0    0.627417    0.483918    0.000000
# radius_mean              569.0   14.127292    3.524049    6.981000
# texture_mean             569.0   19.289649    4.301036    9.710000
# perimeter_mean           569.0   91.969033   24.298981   43.790000
# area_mean                569.0  654.889104  351.914129  143.500000
# smoothness_mean          569.0    0.096360    0.014064    0.052630
# compactness_mean         569.0    0.104341    0.052813    0.019380
# concavity_mean           569.0    0.088799    0.079720    0.000000
# concave points_mean      569.0    0.048919    0.038803    0.000000
# symmetry_mean            569.0    0.181162    0.027414    0.106000
# fractal_dimension_mean   569.0    0.062798    0.007060    0.049960
# radius_se                569.0    0.405172    0.277313    0.111500
# texture_se               569.0    1.216853    0.551648    0.360200
# ...

# %%
#Identifions les caracteristiques avec les plus grandes variances
variances = df.drop("diagnosis", axis = 1).var().sort_values(ascending = False)

# %%
#Top 10 des caracteristiques avec les plus grandes variances
#top10_feat = variances[:10]
top10_feat = variances.head(10)
print(type(top10_feat))
top10_feat
# Out:
# <class 'pandas.core.series.Series'>
# area_worst         324167.385102
# area_mean          123843.554318
# area_se              2069.431583
# perimeter_worst      1129.130847
# perimeter_mean        590.440480
# texture_worst          37.776483
# radius_worst           23.360224
# texture_mean           18.498909
# radius_mean            12.418920
# perimeter_se            4.087896
# dtype: float64

# %%
# Histogrammes des 6 caracteristiques les plus importantes
top6_feat_name = top10_feat.index[:6] #affiche les index
plt.figure(figsize = (20,20))
#plt.subplots(figsize = (20, 20))
for i, feature in enumerate(top6_feat_name) :
    plt.subplot(2, 3, i+1)
    sns.histplot(df[feature], kde = True, bins = 30)
    plt.title(f"Histogramme de {feature}")

# %%
from scipy import stats
stat, p_value = stats.normaltest(df.texture_worst)
if(p_value < 0.05) :
    print("ne suit pas une loi normale")
else :
    print("suit une loi normale")

print(f"skewness de texture_worst : {df["texture_worst"].skew()}")
# Out:
# ne suit pas une loi normale
# skewness de texture_worst : 0.49832130948716474

# %%
#Tracer le boxplot des 6 caracteristiques les plus importantes puis determiner les outliers
plt.figure(figsize = (20,20))
#plt.subplots(figsize = (20, 20))
for i, feature in enumerate(top6_feat_name) :
    plt.subplot(2, 3, i+1)
    sns.boxplot(df[feature])
    plt.title(f"Boxplot de {feature}")

# %%
#Matrice de correlation 
cor = df.corr()
plt.figure(figsize = (35, 35))
cmaps = ['viridis', 'Blues', 'RdBu', 'hot', 'coolwarm', 'YlOrBr']
sns.heatmap(cor, annot = True, cmap = cmaps[4])
plt.title("Matrice de correlation")
# Out:
# Text(0.5, 1.0, 'Matrice de correlation')

# %%
#Top 10 des caracteristiques les plus correlees avec diagnosis
cor_target = cor["diagnosis"].drop("diagnosis").abs().sort_values(ascending = False)
top10_cor_features = cor_target.head(10)
top10_cor_features
# Out:
# concave points_worst    0.793566
# perimeter_worst         0.782914
# concave points_mean     0.776614
# radius_worst            0.776454
# perimeter_mean          0.742636
# area_worst              0.733825
# radius_mean             0.730029
# area_mean               0.708984
# concavity_mean          0.696360
# concavity_worst         0.659610
# Name: diagnosis, dtype: float64
